# %% [markdown]
# # SMILES lookup
#
# Using the SMILES data extracted from Wikipedia by [Ertl et al (2015)](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-015-0061-y), and matching by molecule name to the data extracted from [PsychonautWiki](https://psychonautwiki.org/wiki/PsychonautWiki).

# %%
import pandas as pd
import numpy as np

print(f"Pandas version {pd.__version__}")
print(f"Numpy version  {np.__version__}")

pd.set_option("display.max_rows", 10)
# Out:
# Pandas version 1.2.5
# Numpy version  1.21.0

# %%
# Load the PsychonautWiki data, treating all columns as strings.
psychonaut = pd.read_csv("psychonaut.csv", converters={i: str for i in range(5)})
psychonaut
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 248       4-HO-DiPT       https://psychonautwiki.org/wiki/4-HO-DiPT
# 249         2C-T-21         https://psychonautwiki.org/wiki/2C-T-21
# 250          2C-T-7          https://psychonautwiki.org/wiki/2C-T-7
# 251             DOI             https://psychonautwiki.org/wiki/DOI
# 252             DOM             https://psychonautwiki.org/wiki/DOM
#
#            class0 class1 class2
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 248  Psychedelics
# 249  Psychedelics
# 250  Psychedelics
# 251  Psychedelics
# 252  Psychedelics
#
# [253 rows x 5 columns]

# %%
wikipedia = pd.read_csv("https://www.cheminfo.org/wikipedia/smiles.txt", header=0, names=["name", "smiles"], sep='\t')

# NB: the wikipedia dataset contains multiple SMILES representations for some molecules
# We remove them here.
wikipedia = wikipedia.drop_duplicates(subset=['name'])
wikipedia
# Out:
#                                              name  \
# 0                                         Aspirin
# 1                                       Acetylene
# 2                          Adenosine triphosphate
# 3                                      Ampicillin
# 4                      Chemistry of ascorbic acid
# ...                                           ...
# 18634                         Pentaphenylantimony
# 18635                    CUMYL-BC-HPMEGACLONE-221
# 18636                           Para-Quaterphenyl
# 18637  3-Quinuclidinyl thiochromane-4-carboxylate
# 18638                                   Dotinurad
#
#                                                   smiles
# 0                                  O=C(C)Oc1ccccc1C(=O)O
# 1                                                    C#C
# 2      O=P(O)(O)OP(=O)(O)OP(=O)(O)OC[C@H]3O[C@@H](n2c...
# 3      CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=CC=C3)N)C(=O...
# 4                   C([C@@H]([C@@H]1C(=C(C(=O)O1)O)O)O)O
# ...                                                  ...
# 18634  C1=CC=C(C=C1)[Sb](C2=CC=CC=C2)(C3=CC=CC=C3)(C4...
# 18635  CC(C)(c1ccccc1)N1C=Cc2n(CC3CC4CCC3C4)c3ccccc3c...
# 18636  C1=CC=C(C=C1)C2=CC=C(C=C2)C3=CC=C(C=C3)C4=CC=C...
# 18637                   O=C(OC1CN2CCC1CC2)C1CCSc2ccccc21
# 18638  C1N(C2=CC=CC=C2S1(=O)=O)C(=O)C3=CC(=C(C(=C3)Cl...
#
# [17985 rows x 2 columns]

# %% [markdown]
# # Merge Psychonaut substances with SMILES from WIkipedia
#
# Merge using keys on from the psychonaut (left) dataframe, to match on the "name" column with the Wikipedia SMILES data.

# %%
matched = pd.merge(psychonaut, wikipedia, on="name", how="left", indicator=True, validate="one_to_one")
matched
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 248       4-HO-DiPT       https://psychonautwiki.org/wiki/4-HO-DiPT
# 249         2C-T-21         https://psychonautwiki.org/wiki/2C-T-21
# 250          2C-T-7          https://psychonautwiki.org/wiki/2C-T-7
# 251             DOI             https://psychonautwiki.org/wiki/DOI
# 252             DOM             https://psychonautwiki.org/wiki/DOM
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 248  Psychedelics
# 249  Psychedelics
# 250  Psychedelics
# 251  Psychedelics
# 252  Psychedelics
#
#                                                 smiles     _merge
# 0                                             C(CCO)CO       both
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...       both
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...       both
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...       both
# 4                                  C1C(CC2=CC=CC=C21)N       both
# ..                                                 ...        ...
# 248                 CC(C)N(CCc1c[nH]c2cccc(O)c12)C(C)C       both
# 249                            COc1cc(SCCF)c(cc1CCN)OC       both
# 250                            COc1cc(SCCC)c(cc1CCN)OC       both
# 251                                                NaN  left_only
# 252                                                NaN  left_only
#
# [253 rows x 7 columns]

# %% [markdown]
# # Which substances were not matched by the above process?
#
# These are records we need to manually find SMILES for.

# %%
unmatched = matched[matched["_merge"] == "left_only"] 
unmatched
# Out:
#       name                                    url        class0       class1  \
# 5     2-FA   https://psychonautwiki.org/wiki/2-FA    Stimulants
# 6    2-FEA  https://psychonautwiki.org/wiki/2-FEA    Stimulants  Entactogens
# 7    2-FMA  https://psychonautwiki.org/wiki/2-FMA    Stimulants
# 25    2M2B   https://psychonautwiki.org/wiki/2M2B    Depressant
# 26    3-FA   https://psychonautwiki.org/wiki/3-FA    Stimulants
# ..     ...                                    ...           ...          ...
# 242  MiPLA  https://psychonautwiki.org/wiki/MIPLA  Psychedelics
# 246    MET    https://psychonautwiki.org/wiki/MET  Psychedelics
# 247    EPT    https://psychonautwiki.org/wiki/EPT  Psychedelics
# 251    DOI    https://psychonautwiki.org/wiki/DOI  Psychedelics
# 252    DOM    https://psychonautwiki.org/wiki/DOM  Psychedelics
#
#     class2 smiles     _merge
# 5             NaN  left_only
# 6             NaN  left_only
# 7             NaN  left_only
# 25            NaN  left_only
# 26            NaN  left_only
# ..     ...    ...        ...
# 242           NaN  left_only
# 246           NaN  left_only
# 247           NaN  left_only
# 251           NaN  left_only
# 252           NaN  left_only
#
# [73 rows x 7 columns]

# %%
unmatched.to_csv("intermediate/unmatched.csv", index=False)

# %% [markdown]
# # Sanity check: which molecules were matched?

# %%
resovled = matched[matched["_merge"] == "both"] 
resovled
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 244          AL-LAD          https://psychonautwiki.org/wiki/AL-LAD
# 245      1P-ETH-LAD      https://psychonautwiki.org/wiki/1P-ETH-LAD
# 248       4-HO-DiPT       https://psychonautwiki.org/wiki/4-HO-DiPT
# 249         2C-T-21         https://psychonautwiki.org/wiki/2C-T-21
# 250          2C-T-7          https://psychonautwiki.org/wiki/2C-T-7
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 244  Psychedelics
# 245  Psychedelics
# 248  Psychedelics
# 249  Psychedelics
# 250  Psychedelics
#
#                                                 smiles _merge
# 0                                             C(CCO)CO   both
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...   both
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...   both
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...   both
# 4                                  C1C(CC2=CC=CC=C21)N   both
# ..                                                 ...    ...
# 244  [H][C@@]12Cc3c[nH]c4cccc(C1=C[C@@H](C(=O)N(CC)...   both
# 245  CCC(=O)N1C=C2C[C@@H]3C(=C[C@H](CN3CC)C(=O)N(CC...   both
# 248                 CC(C)N(CCc1c[nH]c2cccc(O)c12)C(C)C   both
# 249                            COc1cc(SCCF)c(cc1CCN)OC   both
# 250                            COc1cc(SCCC)c(cc1CCN)OC   both
#
# [180 rows x 7 columns]

# %% [markdown]
# # Locate SMILES for "missing" records
#
# Looking at the "missing.txt" compound names, try to match up with Wikipedia records to find SMILES values.

# %%
missing = pd.read_csv("intermediate/missing.txt", header=0, names=["name"], sep="\t")
missing = missing.drop_duplicates(subset=['name'])
missing
# Out:
#           name
# 0     2-Me-DET
# 1     2-Me-DMT
# 2     25E-NBOH
# 3    25E-NBOMe
# 4    25G-NBOMe
# ..         ...
# 197    2C-T-15
# 198    2C-T-16
# 199    2C-T-17
# 200    2C-T-18
# 201        BOD
#
# [201 rows x 1 columns]

# %% [markdown]
# # Match the missing substances against the Wikipedia dataset
#
# And how many did we find from this process?

# %%
matched_missing = pd.merge(missing, wikipedia, on="name", how="left", indicator=True, validate="one_to_one")

# %%
is_found = (matched_missing["_merge"] == "both")
found_missing = matched_missing[is_found]
found_missing
# Out:
#           name                                      smiles _merge
# 0     2-Me-DET              c1cccc2c1c(c([nH]2)C)CCN(CC)CC   both
# 2     25E-NBOH       CCC1=CC(=C(C=C1OC)CCNCC2=CC=CC=C2O)OC   both
# 3    25E-NBOMe  COC(C=CC=C1)=C1CNCCC2=C(OC)C=C(CC)C(OC)=C2   both
# 4    25G-NBOMe    CC1=C(C=C(C(=C1C)OC)CCNCC2=CC=CC=C2OC)OC   both
# 5    25H-NBOMe        COC1=CC(=C(C=C1)OC)CCNCC2=CC=CC=C2OC   both
# ..         ...                                         ...    ...
# 189     2C-T-8                  COc2cc(SCC1CC1)c(cc2CCN)OC   both
# 194    2C-T-13                    COc1cc(SCCOC)c(cc1CCN)OC   both
# 196    2C-T-15                   COc2cc(SC1CC1)c(cc2CCN)OC   both
# 197    2C-T-16                    COc1cc(SCC=C)c(OC)cc1CCN   both
# 198    2C-T-17                  CC(CC)Sc1cc(OC)c(cc1OC)CCN   both
#
# [82 rows x 3 columns]

# %% [markdown]
# # Combine "found_missing" records and "matched" records
#
# And write to CSV

# %%
combined = pd.concat([matched, found_missing], axis=0, ignore_index=True)
combined
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 330          2C-T-8                                             NaN
# 331         2C-T-13                                             NaN
# 332         2C-T-15                                             NaN
# 333         2C-T-16                                             NaN
# 334         2C-T-17                                             NaN
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 330           NaN    NaN    NaN
# 331           NaN    NaN    NaN
# 332           NaN    NaN    NaN
# 333           NaN    NaN    NaN
# 334           NaN    NaN    NaN
#
#                                                 smiles _merge
# 0                                             C(CCO)CO   both
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...   both
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...   both
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...   both
# 4                                  C1C(CC2=CC=CC=C21)N   both
# ..                                                 ...    ...
# 330                         COc2cc(SCC1CC1)c(cc2CCN)OC   both
# 331                           COc1cc(SCCOC)c(cc1CCN)OC   both
# 332                          COc2cc(SC1CC1)c(cc2CCN)OC   both
# 333                           COc1cc(SCC=C)c(OC)cc1CCN   both
# 334                         CC(CC)Sc1cc(OC)c(cc1OC)CCN   both
#
# [335 rows x 7 columns]

# %%
combined.to_csv("intermediate/combined.csv", index=False)

# %% [markdown]
# # Merge in the manually curated records to create a library.csv

# %%
manually_found = pd.read_csv("intermediate/manually-found.csv", converters={i: str for i in range(8)})
manually_found
# Out:
#      name                                    url        class0       class1  \
# 0    2-FA   https://psychonautwiki.org/wiki/2-FA    Stimulants
# 1   2-FEA  https://psychonautwiki.org/wiki/2-FEA    Stimulants  Entactogens
# 2   2-FMA  https://psychonautwiki.org/wiki/2-FMA    Stimulants
# 3    2M2B   https://psychonautwiki.org/wiki/2M2B    Depressant
# 4    3-FA   https://psychonautwiki.org/wiki/3-FA    Stimulants
# ..    ...                                    ...           ...          ...
# 68  MiPLA  https://psychonautwiki.org/wiki/MIPLA  Psychedelics
# 69    MET    https://psychonautwiki.org/wiki/MET  Psychedelics
# 70    EPT    https://psychonautwiki.org/wiki/EPT  Psychedelics
# 71    DOI    https://psychonautwiki.org/wiki/DOI  Psychedelics
# 72    DOM    https://psychonautwiki.org/wiki/DOM  Psychedelics
#
#    class2                                           smiles  \
# 0                                       CC(CC1=CC=CC=C1F)N
# 1                                        CCNC(Cc1ccccc1F)C
# 2                                      CC(CC1=CC=CC=C1F)NC
# 3                                               CCC(C)(C)O
# 4                                        Fc1cccc(c1)CC(C)N
# ..    ...                                              ...
# 68         C4N(C)C1Cc2c[nH]c(ccc3)c2c3C1=CC4C(=O)N(C)C(C)C
# 69                              c1cccc2c1c(c[nH]2)CCN(CC)C
# 70                             CCCN(CC)CCC1=CNC2=CC=CC=C12
# 71                              IC(C=C1OC)=C(OC)C=C1CC(C)N
# 72                           O(c1cc(c(OC)cc1C[C@H](N)C)C)C
#
#                                         wikipedia_url  \
# 0   https://en.wikipedia.org/wiki/2-Fluoroamphetamine
# 1
# 2   https://en.wikipedia.org/wiki/2-Fluoromethamph...
# 3     https://en.wikipedia.org/wiki/Tert-Amyl_alcohol
# 4   https://en.wikipedia.org/wiki/3-Fluoroamphetamine
# ..                                                ...
# 68  https://en.wikipedia.org/wiki/Methylisopropyll...
# 69  https://en.wikipedia.org/wiki/N-Methyl-N-ethyl...
# 70  https://en.wikipedia.org/wiki/Ethylpropyltrypt...
# 71  https://en.wikipedia.org/wiki/2,5-Dimethoxy-4-...
# 72  https://en.wikipedia.org/wiki/2,5-Dimethoxy-4-...
#
#                                      isomerdesign_url
# 0
# 1   https://isomerdesign.com/PiHKAL/explore.php?do...
# 2
# 3
# 4
# ..                                                ...
# 68
# 69
# 70
# 71
# 72
#
# [73 rows x 8 columns]

# %%
for index, m in manually_found.iterrows():
    match = (combined["name"] == m["name"])
    combined.loc[match, "smiles"] = m["smiles"]
    
combined
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 330          2C-T-8                                             NaN
# 331         2C-T-13                                             NaN
# 332         2C-T-15                                             NaN
# 333         2C-T-16                                             NaN
# 334         2C-T-17                                             NaN
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 330           NaN    NaN    NaN
# 331           NaN    NaN    NaN
# 332           NaN    NaN    NaN
# 333           NaN    NaN    NaN
# 334           NaN    NaN    NaN
#
#                                                 smiles _merge
# 0                                             C(CCO)CO   both
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...   both
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...   both
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...   both
# 4                                  C1C(CC2=CC=CC=C21)N   both
# ..                                                 ...    ...
# 330                         COc2cc(SCC1CC1)c(cc2CCN)OC   both
# 331                           COc1cc(SCCOC)c(cc1CCN)OC   both
# 332                          COc2cc(SC1CC1)c(cc2CCN)OC   both
# 333                           COc1cc(SCC=C)c(OC)cc1CCN   both
# 334                         CC(CC)Sc1cc(OC)c(cc1OC)CCN   both
#
# [335 rows x 7 columns]

# %%
# remove the `_merge` indicator 
library = combined.drop(["_merge"], axis=1)

# %%
library.to_csv("library.csv", index=False)

# %%
library
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 330          2C-T-8                                             NaN
# 331         2C-T-13                                             NaN
# 332         2C-T-15                                             NaN
# 333         2C-T-16                                             NaN
# 334         2C-T-17                                             NaN
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 330           NaN    NaN    NaN
# 331           NaN    NaN    NaN
# 332           NaN    NaN    NaN
# 333           NaN    NaN    NaN
# 334           NaN    NaN    NaN
#
#                                                 smiles
# 0                                             C(CCO)CO
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...
# 4                                  C1C(CC2=CC=CC=C21)N
# ..                                                 ...
# 330                         COc2cc(SCC1CC1)c(cc2CCN)OC
# 331                           COc1cc(SCCOC)c(cc1CCN)OC
# 332                          COc2cc(SC1CC1)c(cc2CCN)OC
# 333                           COc1cc(SCC=C)c(OC)cc1CCN
# 334                         CC(CC)Sc1cc(OC)c(cc1OC)CCN
#
# [335 rows x 6 columns]

# %% [markdown]
# # Count of class frequency
#
# Combining class0, 1, and 2 into a single class column to see how popular each class is in in the combined data.

# %%
classes = pd.melt(library, id_vars='name', var_name="original_class_column", value_vars=["class0", "class1", "class2"], value_name='class')
counts = pd.DataFrame( classes["class"].value_counts() )
counts
# Out:
#                class
#                  483
# Psychedelics      77
# Stimulants        58
# Depressant        32
# Entactogens       23
# ...              ...
# Antipsychotic      4
# Deliriant          3
# Oneirogen          2
# Eugeroic           1
# Sedative           1
#
# [15 rows x 1 columns]

# %%
counts.to_markdown("intermediate/counts.md")

# %% [markdown]
# # Which compounds are classed as Psychedelic?

# %%
c0 = (library["class0"] == "Psychedelics")
c1 = (library["class1"] == "Psychedelics")

pd.concat(library.loc[c0] library.loc[c1])
#library[is_psychedeics]
# Out:
#     name  url class0 class1 class2 smiles
# 1    NaN  NaN    NaN    NaN    NaN    NaN
# 2    NaN  NaN    NaN    NaN    NaN    NaN
# 3    NaN  NaN    NaN    NaN    NaN    NaN
# 9    NaN  NaN    NaN    NaN    NaN    NaN
# 10   NaN  NaN    NaN    NaN    NaN    NaN
# ..   ...  ...    ...    ...    ...    ...
# 248  NaN  NaN    NaN    NaN    NaN    NaN
# 249  NaN  NaN    NaN    NaN    NaN    NaN
# 250  NaN  NaN    NaN    NaN    NaN    NaN
# 251  NaN  NaN    NaN    NaN    NaN    NaN
# 252  NaN  NaN    NaN    NaN    NaN    NaN
#
# [77 rows x 6 columns]

# %%
#classes[is_psychedeics].to_csv("intermediate/psychedeics.csv")
