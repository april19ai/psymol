# %% [markdown]
# # SMILES lookup
#
# Using the SMILES data extracted from Wikipedia by [Ertl et al (2015)](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-015-0061-y), and matching by molecule name to the data extracted from [PsychonautWiki](https://psychonautwiki.org/wiki/PsychonautWiki).

# %%
import pandas as pd

print(f"Pandas version {pd.__version__}")

pd.set_option("display.max_rows", 10)
# Out:
# Pandas version 1.2.4

# %%
# Load the PsychonautWiki data, treating all columns as strings.
psychonaut = pd.read_csv("psychonaut.csv", converters={i: str for i in range(5)})
psychonaut
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 254       4-HO-DiPT       https://psychonautwiki.org/wiki/4-HO-DiPT
# 255         2C-T-21         https://psychonautwiki.org/wiki/2C-T-21
# 256          2C-T-7          https://psychonautwiki.org/wiki/2C-T-7
# 257             DOI             https://psychonautwiki.org/wiki/DOI
# 258             DOM             https://psychonautwiki.org/wiki/DOM
#
#            class0 class1 class2
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 254  Psychedelics
# 255  Psychedelics
# 256  Psychedelics
# 257  Psychedelics
# 258  Psychedelics
#
# [259 rows x 5 columns]

# %%
wikipedia = pd.read_csv("https://www.cheminfo.org/wikipedia/smiles.txt", header=0, names=["name", "smiles"], sep='\t')

# NB: the wikipedia dataset contains multiple SMILES representations for some molecules
# We remove them here.
wikipedia = wikipedia.drop_duplicates(subset=['name'])
wikipedia
# Out:
#                              name  \
# 0                         Aspirin
# 1                       Acetylene
# 2          Adenosine triphosphate
# 3                      Ampicillin
# 4      Chemistry of ascorbic acid
# ...                           ...
# 18616              Copper oxalate
# 18617                   4-PrO-DMT
# 18618                Phenylcobalt
# 18619        Praseodymium nitride
# 18620   Praseodymium(IV) fluoride
#
#                                                   smiles
# 0                                  O=C(C)Oc1ccccc1C(=O)O
# 1                                                    C#C
# 2      O=P(O)(O)OP(=O)(O)OP(=O)(O)OC[C@H]3O[C@@H](n2c...
# 3      CC1(C(N2C(S1)C(C2=O)NC(=O)C(C3=CC=CC=C3)N)C(=O...
# 4                   C([C@@H]([C@@H]1C(=C(C(=O)O1)O)O)O)O
# ...                                                  ...
# 18616                              C(=O)(C(=O)O)O.[Cu+2]
# 18617                 CCC(=O)OC1=CC=CC2=C1C(=CN2)CCN(C)C
# 18618                                C1=CC=[C-]C=C1.[Co]
# 18619                                             N#[Pr]
# 18620                                       F[Pr](F)(F)F
#
# [17968 rows x 2 columns]

# %%
# Merge using keys on from the psychonaut (left) dataframe, 
# to match on the "name" column with the Wikipedia SMILES data.

matched = pd.merge(psychonaut, wikipedia, on="name", how="left", indicator=True, validate="one_to_one")
matched
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 254       4-HO-DiPT       https://psychonautwiki.org/wiki/4-HO-DiPT
# 255         2C-T-21         https://psychonautwiki.org/wiki/2C-T-21
# 256          2C-T-7          https://psychonautwiki.org/wiki/2C-T-7
# 257             DOI             https://psychonautwiki.org/wiki/DOI
# 258             DOM             https://psychonautwiki.org/wiki/DOM
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 254  Psychedelics
# 255  Psychedelics
# 256  Psychedelics
# 257  Psychedelics
# 258  Psychedelics
#
#                                                 smiles     _merge
# 0                                             C(CCO)CO       both
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...       both
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...       both
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...       both
# 4                                  C1C(CC2=CC=CC=C21)N       both
# ..                                                 ...        ...
# 254                 CC(C)N(CCc1c[nH]c2cccc(O)c12)C(C)C       both
# 255                            COc1cc(SCCF)c(cc1CCN)OC       both
# 256                            COc1cc(SCCC)c(cc1CCN)OC       both
# 257                                                NaN  left_only
# 258                                                NaN  left_only
#
# [259 rows x 7 columns]

# %%
unmatched = matched[matched["_merge"] == "left_only"] 
unmatched
# Out:
#       name                                    url        class0       class1  \
# 5     2-FA   https://psychonautwiki.org/wiki/2-FA    Stimulants
# 6    2-FEA  https://psychonautwiki.org/wiki/2-FEA    Stimulants  Entactogens
# 7    2-FMA  https://psychonautwiki.org/wiki/2-FMA    Stimulants
# 25    2M2B   https://psychonautwiki.org/wiki/2M2B    Depressant
# 26    3-FA   https://psychonautwiki.org/wiki/3-FA    Stimulants
# ..     ...                                    ...           ...          ...
# 248  MiPLA  https://psychonautwiki.org/wiki/MIPLA  Psychedelics
# 252    MET    https://psychonautwiki.org/wiki/MET  Psychedelics
# 253    EPT    https://psychonautwiki.org/wiki/EPT  Psychedelics
# 257    DOI    https://psychonautwiki.org/wiki/DOI  Psychedelics
# 258    DOM    https://psychonautwiki.org/wiki/DOM  Psychedelics
#
#     class2 smiles     _merge
# 5             NaN  left_only
# 6             NaN  left_only
# 7             NaN  left_only
# 25            NaN  left_only
# 26            NaN  left_only
# ..     ...    ...        ...
# 248           NaN  left_only
# 252           NaN  left_only
# 253           NaN  left_only
# 257           NaN  left_only
# 258           NaN  left_only
#
# [79 rows x 7 columns]

# %%
unmatched.to_csv("unmatched.csv", index=False)

# %%
resovled = matched[matched["_merge"] == "both"] 
resovled
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 250          AL-LAD          https://psychonautwiki.org/wiki/AL-LAD
# 251      1P-ETH-LAD      https://psychonautwiki.org/wiki/1P-ETH-LAD
# 254       4-HO-DiPT       https://psychonautwiki.org/wiki/4-HO-DiPT
# 255         2C-T-21         https://psychonautwiki.org/wiki/2C-T-21
# 256          2C-T-7          https://psychonautwiki.org/wiki/2C-T-7
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 250  Psychedelics
# 251  Psychedelics
# 254  Psychedelics
# 255  Psychedelics
# 256  Psychedelics
#
#                                                 smiles _merge
# 0                                             C(CCO)CO   both
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...   both
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...   both
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...   both
# 4                                  C1C(CC2=CC=CC=C21)N   both
# ..                                                 ...    ...
# 250  [H][C@@]12Cc3c[nH]c4cccc(C1=C[C@@H](C(=O)N(CC)...   both
# 251  CCC(=O)N1C=C2C[C@@H]3C(=C[C@H](CN3CC)C(=O)N(CC...   both
# 254                 CC(C)N(CCc1c[nH]c2cccc(O)c12)C(C)C   both
# 255                            COc1cc(SCCF)c(cc1CCN)OC   both
# 256                            COc1cc(SCCC)c(cc1CCN)OC   both
#
# [180 rows x 7 columns]

# %% [markdown]
# # Locate SMILES for "missing" records
#
# Looking at the "missing.txt" compound names, try to match up with Wikipedia records to find SMILES values.

# %%
missing = pd.read_csv("missing.txt", header=0, names=["name"], sep="\t")
missing = missing.drop_duplicates(subset=['name'])
missing
# Out:
#           name
# 0     2-Me-DET
# 1     2-Me-DMT
# 2     25E-NBOH
# 3    25E-NBOMe
# 4    25G-NBOMe
# ..         ...
# 197    2C-T-15
# 198    2C-T-16
# 199    2C-T-17
# 200    2C-T-18
# 201        BOD
#
# [201 rows x 1 columns]

# %%
matched_missing = pd.merge(missing, wikipedia, on="name", how="left", indicator=True, validate="one_to_one")

# %%
is_found = (matched_missing["_merge"] == "both")
found = matched_missing[is_found]
found
# Out:
#           name                                      smiles _merge
# 0     2-Me-DET              c1cccc2c1c(c([nH]2)C)CCN(CC)CC   both
# 2     25E-NBOH       CCC1=CC(=C(C=C1OC)CCNCC2=CC=CC=C2O)OC   both
# 3    25E-NBOMe  COC(C=CC=C1)=C1CNCCC2=C(OC)C=C(CC)C(OC)=C2   both
# 4    25G-NBOMe    CC1=C(C=C(C(=C1C)OC)CCNCC2=CC=CC=C2OC)OC   both
# 5    25H-NBOMe        COC1=CC(=C(C=C1)OC)CCNCC2=CC=CC=C2OC   both
# ..         ...                                         ...    ...
# 189     2C-T-8                  COc2cc(SCC1CC1)c(cc2CCN)OC   both
# 194    2C-T-13                    COc1cc(SCCOC)c(cc1CCN)OC   both
# 196    2C-T-15                   COc2cc(SC1CC1)c(cc2CCN)OC   both
# 197    2C-T-16                    COc1cc(SCC=C)c(OC)cc1CCN   both
# 198    2C-T-17                  CC(CC)Sc1cc(OC)c(cc1OC)CCN   both
#
# [82 rows x 3 columns]

# %% [markdown]
# # Combine "found" records and "matched" records
#
# And write to CSV

# %%
combined = pd.concat([matched, found], axis=0, ignore_index=True)
combined
# Out:
#                name                                             url  \
# 0    1,4-Butanediol  https://psychonautwiki.org/wiki/1,4-Butanediol
# 1            1B-LSD          https://psychonautwiki.org/wiki/1B-LSD
# 2            1P-LSD          https://psychonautwiki.org/wiki/1P-LSD
# 3           1cP-LSD         https://psychonautwiki.org/wiki/1cP-LSD
# 4     2-Aminoindane   https://psychonautwiki.org/wiki/2-Aminoindane
# ..              ...                                             ...
# 336          2C-T-8                                             NaN
# 337         2C-T-13                                             NaN
# 338         2C-T-15                                             NaN
# 339         2C-T-16                                             NaN
# 340         2C-T-17                                             NaN
#
#            class0 class1 class2  \
# 0      Depressant
# 1    Psychedelics
# 2    Psychedelics
# 3    Psychedelics
# 4      Stimulants
# ..            ...    ...    ...
# 336           NaN    NaN    NaN
# 337           NaN    NaN    NaN
# 338           NaN    NaN    NaN
# 339           NaN    NaN    NaN
# 340           NaN    NaN    NaN
#
#                                                 smiles _merge
# 0                                             C(CCO)CO   both
# 1    CN1[C@](C2=C[C@@H](C(N(CC)CC)=O)C1)([H])CC3=CN...   both
# 2    CCN(CC)C(=O)[C@H]1CN(C)[C@@H]2Cc3cn(C(=O)CC)c4...   both
# 3    CCN(CC)C(=O)[C@@H]5C=C2[C@@H](Cc3cn(C(=O)C1CC1...   both
# 4                                  C1C(CC2=CC=CC=C21)N   both
# ..                                                 ...    ...
# 336                         COc2cc(SCC1CC1)c(cc2CCN)OC   both
# 337                           COc1cc(SCCOC)c(cc1CCN)OC   both
# 338                          COc2cc(SC1CC1)c(cc2CCN)OC   both
# 339                           COc1cc(SCC=C)c(OC)cc1CCN   both
# 340                         CC(CC)Sc1cc(OC)c(cc1OC)CCN   both
#
# [341 rows x 7 columns]

# %%
combined.to_csv("combined.csv", index=False)

# %% [markdown]
# # Count of class frequency
#
# Combining class0, 1, and 2 into a single class column to see how popular each class is in in the combined data.

# %%
classes = pd.melt(combined, id_vars='name', var_name="original_class_column", value_vars=["class0", "class1", "class2"], value_name='class')
classes["class"].value_counts()
# Out:
#                  495
# Psychedelics      78
# Stimulants        59
# Depressant        33
# Entactogens       23
# Opioids           22
# Dissociatives     22
# Nootropic         19
# Cannabinoid       10
# Deliriant          4
# Antipsychotic      4
# Hallucinogens      4
# Oneirogen          2
# Sedative           1
# Eugeroic           1
# Name: class, dtype: int64

# %%
is_psychedeics = (classes["class"] == "Psychedelics")
classes[is_psychedeics]
# Out:
#          name original_class_column         class
# 1      1B-LSD                class0  Psychedelics
# 2      1P-LSD                class0  Psychedelics
# 3     1cP-LSD                class0  Psychedelics
# 9    25B-NBOH                class0  Psychedelics
# 10   25C-NBOH                class0  Psychedelics
# ..        ...                   ...           ...
# 258       DOM                class0  Psychedelics
# 362      2C-H                class1  Psychedelics
# 487       MDA                class1  Psychedelics
# 557     TMA-2                class1  Psychedelics
# 558     TMA-6                class1  Psychedelics
#
# [78 rows x 3 columns]

# %%
# Display all the psychedelics
pd.set_option("display.max_rows", None)
classes[is_psychedeics]
# Out:
#                   name original_class_column         class
# 1               1B-LSD                class0  Psychedelics
# 2               1P-LSD                class0  Psychedelics
# 3              1cP-LSD                class0  Psychedelics
# 9             25B-NBOH                class0  Psychedelics
# 10            25C-NBOH                class0  Psychedelics
# 11           25C-NBOMe                class0  Psychedelics
# 12           25D-NBOMe                class0  Psychedelics
# 13            25I-NBOH                class0  Psychedelics
# 14           25I-NBOMe                class0  Psychedelics
# 15           25N-NBOMe                class0  Psychedelics
# 16                2C-B                class0  Psychedelics
# 17            2C-B-FLY                class0  Psychedelics
# 18                2C-C                class0  Psychedelics
# 19                2C-D                class0  Psychedelics
# 20                2C-E                class0  Psychedelics
# 22                2C-I                class0  Psychedelics
# 23                2C-P                class0  Psychedelics
# 24              2C-T-2                class0  Psychedelics
# 37                3C-E                class0  Psychedelics
# 38           4-AcO-DET                class0  Psychedelics
# 39           4-AcO-DMT                class0  Psychedelics
# 40           4-AcO-MET                class0  Psychedelics
# 41          4-AcO-MiPT                class0  Psychedelics
# 44            4-HO-EPT                class0  Psychedelics
# 45            4-HO-MET                class0  Psychedelics
# 46            4-HO-MPT                class0  Psychedelics
# 47           4-HO-MiPT                class0  Psychedelics
# 53          5-MeO-DALT                class0  Psychedelics
# 54           5-MeO-DMT                class0  Psychedelics
# 55          5-MeO-DiBF                class0  Psychedelics
# 56          5-MeO-MiPT                class0  Psychedelics
# 59               6-APB                class0  Psychedelics
# 64              ALD-52                class0  Psychedelics
# 74           Ayahuasca                class0  Psychedelics
# 94                 DET                class0  Psychedelics
# 95                 DMT                class0  Psychedelics
# 96                 DOB                class0  Psychedelics
# 97                 DOC                class0  Psychedelics
# 98                 DPT                class0  Psychedelics
# 105               DiPT                class0  Psychedelics
# 115           Escaline                class0  Psychedelics
# 133           Ibogaine                class0  Psychedelics
# 139                LSA                class0  Psychedelics
# 140                LSD                class0  Psychedelics
# 141            LSM-775                class0  Psychedelics
# 142                LSZ                class0  Psychedelics
# 150                MPT                class0  Psychedelics
# 155          Mescaline                class0  Psychedelics
# 167               MiPT                class0  Psychedelics
# 186          PARGY-LAD                class0  Psychedelics
# 204           Psilocin                class0  Psychedelics
# 229                AMT                class0  Psychedelics
# 230            _k-2C-B                class0  Psychedelics
# 231         4-AcO-DiPT                class0  Psychedelics
# 232           4-HO-DET                class0  Psychedelics
# 233           4-HO-DPT                class0  Psychedelics
# 235          Bufotenin                class0  Psychedelics
# 236         5-MeO-DiPT                class0  Psychedelics
# 240         Proscaline                class0  Psychedelics
# 241      Allylescaline                class0  Psychedelics
# 242  Methallylescaline                class0  Psychedelics
# 246    Bromo-DragonFLY                class0  Psychedelics
# 247            PRO-LAD                class0  Psychedelics
# 248              MiPLA                class0  Psychedelics
# 249            ETH-LAD                class0  Psychedelics
# 250             AL-LAD                class0  Psychedelics
# 251         1P-ETH-LAD                class0  Psychedelics
# 252                MET                class0  Psychedelics
# 253                EPT                class0  Psychedelics
# 254          4-HO-DiPT                class0  Psychedelics
# 255            2C-T-21                class0  Psychedelics
# 256             2C-T-7                class0  Psychedelics
# 257                DOI                class0  Psychedelics
# 258                DOM                class0  Psychedelics
# 362               2C-H                class1  Psychedelics
# 487                MDA                class1  Psychedelics
# 557              TMA-2                class1  Psychedelics
# 558              TMA-6                class1  Psychedelics
